# %% [markdown]
# # 00 — Data Check
#
# 環境・`cg-lib` の有無・カードマスタ件数を確認するノートブック。
#
# ## 手順
#
# 1. ローカル: `input/raw/cg-lib` を配置、または Kaggle で Input を追加
# 2. 下のセルを順に実行

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import CG_LIB_DIR, INPUT_DIR, SAMPLE_DECK
from src.utils import cg_lib_status, setup_cg_lib

print("PROJECT_ROOT:", PROJECT_ROOT)
print("INPUT_DIR:", INPUT_DIR)
print("CG_LIB_DIR (local):", CG_LIB_DIR)
print("cg-lib status:", cg_lib_status())

# %%
cg_path = setup_cg_lib()
print("Using cg-lib:", cg_path)

from cg.api import all_attack, all_card_data

cards = all_card_data()
attacks = all_attack()
print("card count:", len(cards))
print("attack count:", len(attacks))
print("max cardId:", max(c.cardId for c in cards))
print("sample deck size:", len(SAMPLE_DECK))
