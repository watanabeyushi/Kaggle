# %% [markdown]
# # 01 — Sample Code Reading
#
# `sample_code/reinforcement-learning-and-mcts-sample-code.ipynb` の読解メモ用ノートブック。
#
# ## 構成
#
# | ブロック | 内容 |
# |----------|------|
# | import + 定数 | `card_count`, Encoder/Decoder 語彙サイズ |
# | `SparseVector` | EmbeddingBag 入力 |
# | `get_encoder_input` | 盤面 → 24 単語 |
# | `get_decoder_input` | 合法手 → 可変単語 |
# | `MyModel` | Transformer Encoder/Decoder |
# | `mcts_agent` | Search API + MCTS |
# | 学習ループ | 自己対戦 → 評価 |

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import SAMPLE_CODE_DIR

sample_nb = SAMPLE_CODE_DIR / "reinforcement-learning-and-mcts-sample-code.ipynb"
print("Sample notebook:", sample_nb)
print("Exists:", sample_nb.exists())

# %% [markdown]
# ## Encoder 24 単語（早見）
#
# 1–8: 自分ベンチ / 9–16: 相手ベンチ / 17–18: アクティブ / 19–20: プレイヤー状態 / 21: 手札 / 22: デッキ構成 / 23: スタジアム / 24: ターン・先攻
#
# ## Decoder インデックス
#
# - 0: 空 / 1–3: END, YES, NO / 4–8: 特殊状態 / 9–13: 数字 / 14+: わざ / その後: カード（Main 8 + SelectContext）
